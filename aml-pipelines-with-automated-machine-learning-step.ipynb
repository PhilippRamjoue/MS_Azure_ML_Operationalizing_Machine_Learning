# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.14.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FP2W4AXL6 to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# quick-starts-ws-120243
# aml-quickstarts-120243
# southcentralus
# b3fb99ab-ce93-4e7d-92ea-a05123349c1b

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'automl-run'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: automl-run,
# Workspace: quick-starts-ws-120243)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "udacity-compute"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "marketing-data"
description_text = ""

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'accuracy'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [27c679a3][e2050e8b-9a67-4cfd-82a3-a3e34bc26f52], (This step will run and generate new outputs)
# Submitted PipelineRun d459ebde-559b-4405-8ca9-4bd4cc224755
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl-run/runs/d459ebde-559b-4405-8ca9-4bd4cc224755?wsid=/subscriptions/b3fb99ab-ce93-4e7d-92ea-a05123349c1b/resourcegroups/aml-quickstarts-120243/workspaces/quick-starts-ws-120243

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: d459ebde-559b-4405-8ca9-4bd4cc224755
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl-run/runs/d459ebde-559b-4405-8ca9-4bd4cc224755?wsid=/subscriptions/b3fb99ab-ce93-4e7d-92ea-a05123349c1b/resourcegroups/aml-quickstarts-120243/workspaces/quick-starts-ws-120243
# PipelineRun Status: Running
#
#
# StepRunId: 13d8a191-43ad-42c7-812c-0c4fb198a440
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl-run/runs/13d8a191-43ad-42c7-812c-0c4fb198a440?wsid=/subscriptions/b3fb99ab-ce93-4e7d-92ea-a05123349c1b/resourcegroups/aml-quickstarts-120243/workspaces/quick-starts-ws-120243
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/13d8a191-43ad-42c7-812c-0c4fb198a440/metrics_data
# Downloaded azureml/13d8a191-43ad-42c7-812c-0c4fb198a440/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_5  \
# matthews_correlation                               [0.3962826053496274]
# accuracy                                           [0.9010622154779969]
# average_precision_score_micro                      [0.9677529320240363]
# recall_score_weighted                              [0.9010622154779969]
# precision_score_weighted                           [0.8847395670558821]
# norm_macro_recall                                  [0.2965191989582232]
# recall_score_micro                                 [0.9010622154779969]
# precision_score_macro                              [0.7648056244830439]
# average_precision_score_weighted                   [0.9372755832799073]
# AUC_weighted                                        [0.921383280818454]
# log_loss                                           [0.2284806042928566]
# AUC_macro                                          [0.9213832808184541]
# balanced_accuracy                                  [0.6482595994791116]
# weighted_accuracy                                  [0.9638262668354637]
# AUC_micro                                          [0.9699330157202364]
# f1_score_micro                                     [0.9010622154779969]
# f1_score_macro                                     [0.6839434554283683]
# precision_score_micro                              [0.9010622154779969]
# average_precision_score_macro                      [0.7555569626361887]
# recall_score_macro                                 [0.6482595994791116]
# f1_score_weighted                                  [0.8872289440577715]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_23  \
# matthews_correlation                                [0.5369833022433826]
# accuracy                                            [0.8628224582701062]
# average_precision_score_micro                       [0.9222139489277026]
# recall_score_weighted                               [0.8628224582701062]
# precision_score_weighted                            [0.9154577672178817]
# norm_macro_recall                                     [0.69395402771526]
# recall_score_micro                                  [0.8628224582701062]
# precision_score_macro                               [0.7077594879285887]
# average_precision_score_weighted                    [0.9381493886635297]
# AUC_weighted                                        [0.9218713820767735]
# log_loss                                            [0.7046342890412395]
# AUC_macro                                           [0.9218713820767737]
# balanced_accuracy                                     [0.84697701385763]
# weighted_accuracy                                   [0.8667564535057051]
# AUC_micro                                           [0.9301151098021787]
# f1_score_micro                                      [0.8628224582701062]
# f1_score_macro                                       [0.746311195052886]
# precision_score_micro                               [0.8628224582701062]
# average_precision_score_macro                       [0.7598771121470627]
# recall_score_macro                                    [0.84697701385763]
# f1_score_weighted                                   [0.8797278094937423]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_27  \
# matthews_correlation                                               [0.0]
# accuracy                                            [0.8880121396054628]
# average_precision_score_micro                       [0.9680111721225139]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_weighted                     [0.927030461979686]
# AUC_weighted                                        [0.8938555738940848]
# log_loss                                            [0.2506050072688875]
# AUC_macro                                           [0.8938555738940848]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                            [0.966347318901817]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_macro                        [0.722899590692632]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_13  \
# matthews_correlation                                               [0.0]
# accuracy                                            [0.8880121396054628]
# average_precision_score_micro                       [0.9671570712839346]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_weighted                    [0.9270986977736413]
# AUC_weighted                                        [0.8926339314657672]
# log_loss                                            [0.2500023367152838]
# AUC_macro                                           [0.8926339314657672]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9661043425800345]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_macro                       [0.7256659442435486]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_22  \
# matthews_correlation                                               [0.0]
# accuracy                                            [0.8880121396054628]
# average_precision_score_micro                        [0.957679770167799]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_weighted                    [0.9149895894879049]
# AUC_weighted                                        [0.8491609659773974]
# log_loss                                           [0.27290444242649337]
# AUC_macro                                           [0.8491609659773973]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                            [0.957457867141321]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_macro                       [0.7000700595363435]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_14  \
# matthews_correlation                                [0.3118550468185577]
# accuracy                                            [0.7216995447647951]
# average_precision_score_micro                       [0.8271152901991841]
# recall_score_weighted                               [0.7216995447647951]
# precision_score_weighted                            [0.8784867073017062]
# norm_macro_recall                                  [0.46635435595640984]
# recall_score_micro                                  [0.7216995447647951]
# precision_score_macro                               [0.6042700352039759]
# average_precision_score_weighted                    [0.9181752353550854]
# AUC_weighted                                        [0.8565237002335847]
# log_loss                                            [0.6008268052644548]
# AUC_macro                                           [0.8565237002335847]
# balanced_accuracy                                   [0.7331771779782049]
# weighted_accuracy                                   [0.7188499589026307]
# AUC_micro                                           [0.8309800336648392]
# f1_score_micro                                      [0.7216995447647951]
# f1_score_macro                                      [0.5983496192681691]
# precision_score_micro                               [0.7216995447647951]
# average_precision_score_macro                       [0.7054686819081459]
# recall_score_macro                                  [0.7331771779782049]
# f1_score_weighted                                   [0.7710800461547369]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_29  \
# matthews_correlation                               [0.43493683624467777]
# accuracy                                            [0.9077389984825494]
# average_precision_score_micro                       [0.9764205400146144]
# recall_score_weighted                               [0.9077389984825494]
# precision_score_weighted                            [0.8939836428165763]
# norm_macro_recall                                  [0.31587931395376834]
# recall_score_micro                                  [0.9077389984825494]
# precision_score_macro                               [0.7994340609942827]
# average_precision_score_weighted                    [0.9447917286233126]
# AUC_weighted                                        [0.9285964356567694]
# log_loss                                           [0.20568151213575123]
# AUC_macro                                           [0.9285964356567693]
# balanced_accuracy                                   [0.6579396569768842]
# weighted_accuracy                                   [0.9697574180205497]
# AUC_micro                                           [0.9752788632245022]
# f1_score_micro                                      [0.9077389984825494]
# f1_score_macro                                      [0.6994637825174859]
# precision_score_micro                               [0.9077389984825494]
# average_precision_score_macro                       [0.7858146212354111]
# recall_score_macro                                  [0.6579396569768842]
# f1_score_weighted                                   [0.8936160709690597]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_33  \
# matthews_correlation                                               [0.0]
# accuracy                                            [0.8880121396054628]
# average_precision_score_micro                       [0.9692264273573841]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_weighted                    [0.9266165841857111]
# AUC_weighted                                        [0.9016892749241914]
# log_loss                                            [0.2381191077084557]
# AUC_macro                                           [0.9016892749241915]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                            [0.967905388446651]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_macro                       [0.7180028662066205]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_32  \
# matthews_correlation                                               [0.0]
# accuracy                                            [0.8880121396054628]
# average_precision_score_micro                       [0.9693265928346296]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_weighted                     [0.930267608138193]
# AUC_weighted                                        [0.9021801547475489]
# log_loss                                            [0.2522470644161428]
# AUC_macro                                           [0.9021801547475489]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9680030210854262]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_macro                       [0.7343757324082404]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_35  ...  \
# matthews_correlation                               [0.19660462274916415]  ...
# accuracy                                            [0.8919575113808801]  ...
# average_precision_score_micro                       [0.9738020117402273]  ...
# recall_score_weighted                               [0.8919575113808801]  ...
# precision_score_weighted                            [0.8678188032189106]  ...
# norm_macro_recall                                  [0.07075430631271451]  ...
# recall_score_micro                                  [0.8919575113808801]  ...
# precision_score_macro                               [0.7731521210560943]  ...
# average_precision_score_weighted                    [0.9416163478746032]  ...
# AUC_weighted                                        [0.9248055467567663]  ...
# log_loss                                           [0.22648622639096552]  ...
# AUC_macro                                           [0.9248055467567663]  ...
# balanced_accuracy                                   [0.5353771531563573]  ...
# weighted_accuracy                                   [0.9804867689925437]  ...
# AUC_micro                                           [0.9726361503266318]  ...
# f1_score_micro                                      [0.8919575113808801]  ...
# f1_score_macro                                      [0.5391492518080128]  ...
# precision_score_micro                               [0.8919575113808801]  ...
# average_precision_score_macro                       [0.7738733991735645]  ...
# recall_score_macro                                  [0.5353771531563573]  ...
# f1_score_weighted                                   [0.8520631330871741]  ...
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_18  \
# matthews_correlation                                [0.3470307653390731]
# accuracy                                            [0.6949924127465857]
# average_precision_score_micro                       [0.8519347500368344]
# recall_score_weighted                               [0.6949924127465857]
# precision_score_weighted                            [0.8936222440417745]
# norm_macro_recall                                   [0.5357462392122212]
# recall_score_micro                                  [0.6949924127465857]
# precision_score_macro                               [0.6123949579831933]
# average_precision_score_weighted                    [0.9239163410109743]
# AUC_weighted                                        [0.8710393870856002]
# log_loss                                            [0.5132786039005354]
# AUC_macro                                           [0.8710393870856002]
# balanced_accuracy                                   [0.7678731196061106]
# weighted_accuracy                                   [0.6768981046231293]
# AUC_micro                                           [0.8351807240012802]
# f1_score_micro                                      [0.6949924127465857]
# f1_score_macro                                      [0.5922486141088832]
# precision_score_micro                               [0.6949924127465857]
# average_precision_score_macro                       [0.7227368676689756]
# recall_score_macro                                  [0.7678731196061106]
# f1_score_weighted                                    [0.751085308858947]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_16  \
# matthews_correlation                                               [0.0]
# accuracy                                            [0.8880121396054628]
# average_precision_score_micro                       [0.9632415618262579]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_weighted                    [0.9268829794374503]
# AUC_weighted                                        [0.8829853643717571]
# log_loss                                            [0.2803135621863842]
# AUC_macro                                           [0.8829853643717571]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9641853085905209]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_macro                       [0.7397240904219329]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_26  \
# matthews_correlation                               [0.49213857715421105]
# accuracy                                            [0.9080424886191198]
# average_precision_score_micro                       [0.9773969896823556]
# recall_score_weighted                               [0.9080424886191198]
# precision_score_weighted                             [0.899969838742595]
# norm_macro_recall                                  [0.43937078468529034]
# recall_score_micro                                  [0.9080424886191198]
# precision_score_macro                               [0.7756218523915434]
# average_precision_score_weighted                    [0.9480034685313283]
# AUC_weighted                                        [0.9319154315945072]
# log_loss                                           [0.19664471940167458]
# AUC_macro                                           [0.9319154315945073]
# balanced_accuracy                                   [0.7196853923426452]
# weighted_accuracy                                    [0.954806460651324]
# AUC_micro                                           [0.9762771109028486]
# f1_score_micro                                        [0.90804248861912]
# f1_score_macro                                      [0.7431757525868666]
# precision_score_micro                               [0.9080424886191198]
# average_precision_score_macro                       [0.7984255787742488]
# recall_score_macro                                  [0.7196853923426452]
# f1_score_weighted                                   [0.9028591783574997]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_11  \
# matthews_correlation                               [0.35008518604522254]
# accuracy                                            [0.9004552352048558]
# average_precision_score_micro                       [0.9723673817026254]
# recall_score_weighted                               [0.9004552352048558]
# precision_score_weighted                            [0.8821451525878488]
# norm_macro_recall                                  [0.21531470953807275]
# recall_score_micro                                  [0.9004552352048558]
# precision_score_macro                               [0.7846058166468338]
# average_precision_score_weighted                    [0.9391639509193688]
# AUC_weighted                                        [0.9156557320870544]
# log_loss                                            [0.2420728545315905]
# AUC_macro                                           [0.9156557320870543]
# balanced_accuracy                                   [0.6076573547690364]
# weighted_accuracy                                   [0.9731490288684157]
# AUC_micro                                           [0.9718690893684043]
# f1_score_micro                                      [0.9004552352048558]
# f1_score_macro                                      [0.6437621793806876]
# precision_score_micro                               [0.9004552352048558]
# average_precision_score_macro                       [0.7692407271301764]
# recall_score_macro                                  [0.6076573547690364]
# f1_score_weighted                                   [0.8784293741402149]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_2  \
# matthews_correlation                               [0.3126383491342832]
# accuracy                                           [0.9001517450682853]
# average_precision_score_micro                      [0.9659070187974609]
# recall_score_weighted                              [0.9001517450682853]
# precision_score_weighted                           [0.8918775939553708]
# norm_macro_recall                                  [0.1368202472181932]
# recall_score_micro                                 [0.9001517450682853]
# precision_score_macro                              [0.8571939801918911]
# average_precision_score_weighted                   [0.9311685368827993]
# AUC_weighted                                       [0.8950142355148772]
# log_loss                                          [0.24524902635261775]
# AUC_macro                                          [0.8950142355148774]
# balanced_accuracy                                  [0.5684101236090966]
# weighted_accuracy                                  [0.9825142162175774]
# AUC_micro                                          [0.9669281409962673]
# f1_score_micro                                     [0.9001517450682853]
# f1_score_macro                                     [0.5933748215009784]
# precision_score_micro                              [0.9001517450682853]
# average_precision_score_macro                      [0.7526619582778613]
# recall_score_macro                                 [0.5684101236090966]
# f1_score_weighted                                  [0.8674588863373179]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_10  \
# matthews_correlation                               [0.35548055817062146]
# accuracy                                            [0.8998482549317147]
# average_precision_score_micro                       [0.9726796938499117]
# recall_score_weighted                               [0.8998482549317147]
# precision_score_weighted                            [0.8809778196384862]
# norm_macro_recall                                  [0.23120902774304564]
# recall_score_micro                                  [0.8998482549317147]
# precision_score_macro                               [0.7732731253420908]
# average_precision_score_weighted                     [0.939696950175479]
# AUC_weighted                                        [0.9172723938449225]
# log_loss                                           [0.24087894591922568]
# AUC_macro                                           [0.9172723938449228]
# balanced_accuracy                                   [0.6156045138715228]
# weighted_accuracy                                   [0.9704182871738612]
# AUC_micro                                           [0.9721608820095744]
# f1_score_micro                                      [0.8998482549317147]
# f1_score_macro                                      [0.6518323031484465]
# precision_score_micro                               [0.8998482549317147]
# average_precision_score_macro                       [0.7702418777028099]
# recall_score_macro                                  [0.6156045138715228]
# f1_score_weighted                                   [0.8798714217064533]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_30  \
# matthews_correlation                                               [0.0]
# accuracy                                            [0.8880121396054628]
# average_precision_score_micro                       [0.9679330034074787]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_weighted                     [0.927202839658634]
# AUC_weighted                                        [0.9038810996448994]
# log_loss                                            [0.3288434356086105]
# AUC_macro                                           [0.9038810996448994]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9683413273894093]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_macro                       [0.7242337312340645]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_28  \
# matthews_correlation                                 [0.504245030791482]
# accuracy                                             [0.908649468892261]
# average_precision_score_micro                       [0.9768020484390596]
# recall_score_weighted                                [0.908649468892261]
# precision_score_weighted                            [0.9020218484251157]
# norm_macro_recall                                  [0.46136868409012166]
# recall_score_micro                                   [0.908649468892261]
# precision_score_macro                               [0.7755530011528002]
# average_precision_score_weighted                    [0.9463238941554014]
# AUC_weighted                                        [0.9304719670573329]
# log_loss                                           [0.19869385781115906]
# AUC_macro                                           [0.9304719670573328]
# balanced_accuracy                                   [0.7306843420450608]
# weighted_accuracy                                    [0.952833396013193]
# AUC_micro                                           [0.9756503277831634]
# f1_score_micro                                       [0.908649468892261]
# f1_score_macro                                      [0.7502813063289329]
# precision_score_micro                                [0.908649468892261]
# average_precision_score_macro                       [0.7916720520086196]
# recall_score_macro                                  [0.7306843420450608]
# f1_score_weighted                                   [0.9046057696194931]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_8  \
# matthews_correlation                               [0.3161462686094845]
# accuracy                                            [0.898937784522003]
# average_precision_score_micro                      [0.9650864996582112]
# recall_score_weighted                               [0.898937784522003]
# precision_score_weighted                           [0.8808938598034951]
# norm_macro_recall                                  [0.1686088836281392]
# recall_score_micro                                  [0.898937784522003]
# precision_score_macro                              [0.7963914504532666]
# average_precision_score_weighted                    [0.927106927547307]
# AUC_weighted                                       [0.8796534017971759]
# log_loss                                          [0.25727721773574014]
# AUC_macro                                          [0.8796534017971759]
# balanced_accuracy                                  [0.5843044418140696]
# weighted_accuracy                                  [0.9770527328284682]
# AUC_micro                                          [0.9639835037682973]
# f1_score_micro                                     [0.8989377845220029]
# f1_score_macro                                       [0.61475181040158]
# precision_score_micro                               [0.898937784522003]
# average_precision_score_macro                      [0.7338248180032351]
# recall_score_macro                                 [0.5843044418140696]
# f1_score_weighted                                  [0.8715233778312342]
#
#                                  13d8a191-43ad-42c7-812c-0c4fb198a440_39
# matthews_correlation                                [0.5193049331294961]
# accuracy                                            [0.9156297420333839]
# average_precision_score_micro                       [0.9798179182929534]
# recall_score_weighted                               [0.9156297420333839]
# precision_score_weighted                            [0.9066384895689457]
# norm_macro_recall                                  [0.43844181777429525]
# recall_score_micro                                  [0.9156297420333839]
# precision_score_macro                               [0.8075409354673568]
# average_precision_score_weighted                    [0.9521442881568111]
# AUC_weighted                                        [0.9411620329463719]
# log_loss                                           [0.19727906684299487]
# AUC_macro                                           [0.9411620329463719]
# balanced_accuracy                                   [0.7192209088871476]
# weighted_accuracy                                   [0.9643927425345529]
# AUC_micro                                           [0.9789043499485356]
# f1_score_micro                                      [0.9156297420333839]
# f1_score_macro                                       [0.753236446471212]
# precision_score_micro                               [0.9156297420333839]
# average_precision_score_macro                        [0.812915763225692]
# recall_score_macro                                  [0.7192209088871476]
# f1_score_weighted                                   [0.9085823711822011]
#
# [21 rows x 38 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/13d8a191-43ad-42c7-812c-0c4fb198a440/model_data
# Downloaded azureml/13d8a191-43ad-42c7-812c-0c4fb198a440/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                    n_jobs=1,
#                                                                                                                                    oob_score=True,
#                                                                                                                                    random_state=None,
#                                                                                                                                    verbose=0,
#                                                                                                                                    warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.3076923076923077,
#                                                                                          0.07692307692307693,
#                                                                                          0.07692307692307693,
#                                                                                          0.23076923076923078,
#                                                                                          0.07692307692307693,
#                                                                                          0.07692307692307693,
#                                                                                          0.07692307692307693,
#                                                                                          0.07692307692307693]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                    min_samples_leaf=0.035789473684210524,
#                                                                                    min_samples_split=0.01,
#                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                    n_estimators=25,
#                                                                                    n_jobs=1,
#                                                                                    oob_score=True,
#                                                                                    random_state=None,
#                                                                                    verbose=0,
#                                                                                    warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.3076923076923077, 0.07692307692307693,
#                                          0.07692307692307693, 0.23076923076923078,
#                                          0.07692307692307693, 0.07692307692307693,
#                                          0.07692307692307693,
#                                          0.07692307692307693]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24row0_col0" class="data row0 col0" >28437</td>
#                         <td id="T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24row0_col1" class="data row0 col1" >821</td>
#             </tr>
#             <tr>
#                         <th id="T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24row1_col0" class="data row1 col0" >1705</td>
#                         <td id="T_9c0b62f2_0a0c_11eb_a37b_000d3a70ad24row1_col1" class="data row1 col1" >1987</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: a742f339-c136-4cac-abb3-e1746c523719,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/b3fb99ab-ce93-4e7d-92ea-a05123349c1b/resourceGroups/aml-quickstarts-120243/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-120243/PipelineRuns/PipelineSubmit/a742f339-c136-4cac-abb3-e1746c523719)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  cb147f5c-5eec-4629-bb28-0e207a89296f

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
